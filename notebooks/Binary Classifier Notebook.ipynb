# %% [markdown]
# <a href="https://colab.research.google.com/github/Najjdorf/ml-binary-classifier/blob/main/Binary%20Classifier%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Binary Classification Project

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 1. Loading the dataset

# %% [markdown]
# ## 2. Exploring the data

# %% [markdown]
# ## 3. Train/validation/test split

# %% [markdown]
# ## 4. Feature scaling

# %% [markdown]
# ## 5. Baseline model

# %% [markdown]
# ## 6. Evaluation

# %% [markdown]
# ## 7. Conclusions
